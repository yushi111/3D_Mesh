# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display
import matplotlib as mlp
import mat73
# %matplotlib inline

# %%
fig=plt.figure()

# %%
A1=np.arange(1,6)
B=A1**2
ax1=fig.add_subplot(331)
ax2=fig.add_subplot(333)
ax3=fig.add_subplot(334)
ax5=fig.add_subplot(336)
ax6=fig.add_subplot(337)
ax7=fig.add_subplot(339)
ax8=fig.add_subplot(132)
ax3.bar(A1,B)
display(fig)
fig.savefig('as')

# %%
A=np.arange(1,5)
B=A**2
C=A**3
fig2,axes=plt.subplots(1,2)
axes[0].plot(A,B)
axes[1].scatter(A,C)
#display(fig2)
fig2.savefig('as.svg')

# %%
fig3=plt.figure()
ax=fig3.add_subplot(projection='3d')
mat=mat73.loadmat('/project/GIMRI_model/results/figures/for_YS/fig1_sub1.mat')
print(mat['vertices'].shape)
#mesh=mlp.tri.Triangulation(mat['vertices'],triangles=mat['faces'])
ax.plot_trisurf(mat['vertices'][:,0],mat['vertices'][:,1],mat['vertices'][2],Z=mat['vertices'][:,2])
display(fig3)
# Out:
# (18650, 3)
